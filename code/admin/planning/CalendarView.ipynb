# %%
# %reload_ext autoreload
# %run Schedule.ipynb

# Goal would be to have 5 categories: released, due, events, holiday, and concepts
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from MplCalendar import MplCalendar
from calendar_helpers import CourseCal

COURSE_YEAR = 2023

# For each month of the course, generate a calendar
months = []
for current_date in syllabus:
    month = current_date.month
    if not (month in months):
        months.append(month)

for month in months:
    cal = CourseCal(COURSE_YEAR, month, syllabus)
    # Color Class Days
    cal.color_class_days("yellow")
    cal.mark_holidays(HOLIDAYS)
    #cal.mark_lessons()
    cal.mark_EX()
    cal.show()
